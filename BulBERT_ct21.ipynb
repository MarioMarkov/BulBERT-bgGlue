# %%
#@title Install libraries
# !pip install --quiet datasets transformers evaluate seqeval accelerate -U jsonlines imbalanced-learn

# %%
#@title Load Libraries
import os
import torch
import evaluate
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset,Dataset, DatasetDict
from transformers import AutoTokenizer, DataCollatorForTokenClassification, \
AutoModelForTokenClassification, AutoModelForMaskedLM, TrainingArguments, Trainer,AutoModelForSequenceClassification,DataCollatorWithPadding

# %%
#@title Load model
model_checkpoint = "mor40/BulBERT-chitanka-model"
model_raw = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=2)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at mor40/BulBERT-chitanka-model and are newly initialized: ['classifier.weight', 'classifier.bias', 'bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#@title Load Dataset
hf_dataset = load_dataset("bgglue/bgglue","ct21t1").remove_columns(["tweet_id"])
hf_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id_str', 'topic_id', 'tweet_text', 'labels'],
#         num_rows: 3000
#     })
#     validation: Dataset({
#         features: ['id_str', 'topic_id', 'tweet_text', 'labels'],
#         num_rows: 350
#     })
#     test: Dataset({
#         features: ['id_str', 'topic_id', 'tweet_text', 'labels'],
#         num_rows: 357
#     })
# })

# %% [markdown]
# ## Train Model

# %%
hf_dataset.set_format('pandas')
hf_dataset["train"][:5]
# Out:
#                                           tweet_text  labels
# 0  Препоръките към държавите-членки в рамките на ...       0
# 1  За тия, дет си мислят, че няма вирус https://t...       0
# 2  Отменят се част от противоепидемичните мерки, ...       0
# 3  Oпазването на биоразнообразието 🦋🐅🐘🌴 остава пр...       0
# 4  Кратък обзор над мерките в сградостроителствот...       0

# %%
hf_dataset["train"]["labels"].value_counts()
# Out:
# 0    2608
# 1     392
# Name: labels, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler


X = hf_dataset["train"]['tweet_text']
y = hf_dataset["train"]['labels']
X_arr = np.array(X).reshape(-1, 1)
# Initialize the RandomOverSampler
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)

# Apply oversampling to your data
X_resampled, y_resampled = oversampler.fit_resample(X_arr, y)
flattened_X = [item for sublist in X_resampled for item in sublist]

# Now you have X_resampled and y_resampled with oversampled data
result_dataset = pd.DataFrame({"tweet_text": flattened_X, "labels":y_resampled })
result_dataset
# Out:
#                                              tweet_text  labels
# 0     Препоръките към държавите-членки в рамките на ...       0
# 1     За тия, дет си мислят, че няма вирус https://t...       0
# 2     Отменят се част от противоепидемичните мерки, ...       0
# 3     Oпазването на биоразнообразието 🦋🐅🐘🌴 остава пр...       0
# 4     Кратък обзор над мерките в сградостроителствот...       0
# ...                                                 ...     ...
# 5211  Посланик на #Азербайджан: #Армения започна таз...       1
# 5212  САЩ и Великобритания спряха за COVID-19 медика...       1
# 5213  Супер интересно, досега не знаех, че ваксини м...       1
# 5214  Андрю Куомо продължава да използва думата Евро...       1
# 5215  COVID-19 рядко води до възпаление на белия дро...       1
#
# [5216 rows x 2 columns]

# %%
result_dataset["labels"].value_counts()
# Out:
# 0    2608
# 1    2608
# Name: labels, dtype: int64

# %%
balanced_train_dataset = Dataset.from_pandas(result_dataset)

# %%
def tokenize(batch):
 return tokenizer(batch["tweet_text"],  truncation=True)


train_tokenzied = balanced_train_dataset.map(tokenize, batched=True, batch_size=None)
hf_dataset["validation"].reset_format()
validation_tokenzied = hf_dataset["validation"].map(tokenize, batched=True, batch_size=None)
# Out:
# Map:   0%|          | 0/5216 [00:00<?, ? examples/s]
# Map:   0%|          | 0/350 [00:00<?, ? examples/s]

# %%
#@title Define model training args
accuracy = evaluate.load("accuracy")
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)


data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(
    "BulBERT-ct21-8pochs",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    num_train_epochs=8,
    weight_decay=0.01,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    push_to_hub=True,
)
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
del args

# %%
del trainer

# %%
del model_raw

# %%
#@title Train
trainer = Trainer(
    model=model_raw,
    args=args,
    train_dataset=train_tokenzied,
    eval_dataset=validation_tokenzied,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
)
trainer.train()

trainer.push_to_hub(commit_message="Training complete")
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='815' max='815' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [815/815 05:40, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.489052</td>
#       <td>0.774286</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.547468</td>
#       <td>0.825714</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.788940</td>
#       <td>0.820000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.288000</td>
#       <td>0.943759</td>
#       <td>0.828571</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.288000</td>
#       <td>1.005149</td>
#       <td>0.840000</td>
#     </tr>
#   </tbody>
# </table><p>
# 'https://huggingface.co/mor40/BulBERT-ct21-5pochs/tree/main/'

# %% [markdown]
# ## Test Model

# %%
from transformers.tools.text_classification import AutoModelForSequenceClassification
checkpoint = "mor40/BulBERT-ct21-5pochs"

model = AutoModelForSequenceClassification.from_pretrained(checkpoint)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/702 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/748k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.54M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
def get_predictions(example, model):
  inputs = tokenizer(example["tweet_text"], return_tensors="pt",truncation = True)
  #actual = example["label"]

  # Run through model
  with torch.no_grad():
        logits = model(**inputs).logits[0]

  label_id = np.argmax(logits).item()
  example["predicted_label"] = label_id

  return example

dataset_validation = hf_dataset["validation"].map(get_predictions,fn_kwargs={"model": model})
dataset_test = hf_dataset["test"].map(get_predictions,fn_kwargs={"model": model})
# Out:
# Map:   0%|          | 0/350 [00:00<?, ? examples/s]
# Map:   0%|          | 0/357 [00:00<?, ? examples/s]

# %%
correct = 0
for i, example in enumerate(dataset_validation):
  if example["predicted_label"] == example["labels"]: correct+=1


print("Accuracy: " ,correct / len(dataset_validation))
# Out:
# Accuracy:  0.84

# %%
dataset_test
# Out:
# Dataset({
#     features: ['id_str', 'topic_id', 'tweet_text', 'labels', 'predicted_label'],
#     num_rows: 357
# })

# %%
predictions = []

for i, example in enumerate(dataset_test):
  rec = {}
  rec['topic_id'] = example['topic_id']
  rec['id_str'] = example['id_str']
  rec['label'] = example["predicted_label"]
  predictions.append(rec)

# %%
predictions
# Out:
# [{'topic_id': 'covid-19', 'id_str': '1241620737565360128', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1293890411052900352', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1294530807349030913', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290911256312975362', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256499987636248576', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1285586200183570434', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1248186232540143616', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1239830696589504513', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1271089562266161152', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1243435022163546112', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1261179521014915073', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1299276141577015297', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1295945515994144770', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264909985177362438', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1274961898346287104', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1289964185238081536', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255377126066466817', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1289788054106906624', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1273286038878777345', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256479854813425669', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1276490398785994753', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253590059212845056', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1295345549353328643', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1280404882864984065', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1298222320515977216', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290591128589406208', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1261190636713250816', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1294194922069819400', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1294262382131400704', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264905413419548672', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1263369114204200960', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1240908850837979137', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1298885584417705989', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1239063936479133696', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1254782153235116034', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1282214642727686146', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1247825444424028160', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257199966898053122', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256971474818207744', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1252822585588383747', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1243971011768455170', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1257628765489958912', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1269883523588112384', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1247119013219643392', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257932121966096384', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1270964960613580800', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1300467621251420160', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253560529764995074', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1284366323036950528', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1276408913945116672', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1249966632094572545', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1265639797021986816', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1284766523844952065', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1289472928812277760', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1296053078853066754', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1252925889022697472', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1239437841735745537', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1270760125200990210', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1247797915805839365', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290544075809206273', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251770681181843456', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1242766567131303936', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1279285158366109698', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1259359735041662977', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1259753486402666496', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257917602267049984', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1254700768311021569', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246695703977627649', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1255914762988408840', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1249964848286437376', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1263788633892372480', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1284627753711607809', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253294488199614467', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1292501371816738817', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290914037681848321', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1297791852561801218', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1287623124633124870', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1298640693980782592', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256466305093378048', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1289117481424973824', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1288983772214460416', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246695690119585792', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1293057192942166017', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1291298070513278976', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1289554326613000193', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1267706567111122946', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256127469276598272', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255445313130725376', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255450009220325376', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1263742166733643776', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1266348517355814914', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1233677960412061697', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1287426507212648450', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1237340286549975041', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1281147494001491968', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1284354564091772929', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1240709244225232896', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1248212048657383425', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1278584171913338880', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1250358428968448000', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1254424450671525889', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1278923378070609920', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1241582871606956032', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246781813680414720', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1233816799302619136', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1233886948948922374', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1278932683305951234', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1271754383726751744', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253227874158608384', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1253199727212068864', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1299769889155100673', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1253634811702411264', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246370522994270210', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1295958683566956545', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1296452311120846848', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1288817877311684611', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1282281193258520585', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1275413188562075648', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1243842288738086912', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1247913529786667008', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251939694058889221', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1255434838758342664', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257930185036439552', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1286596377192128512', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251154173795594240', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1231848070297640960', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1298499003437453313', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1236601683863535617', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1262303684844826624', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1243806876724277250', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249950018112552965', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1268801120664793088', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1273534564875546625', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1264615694341152775', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1258003135349567488', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249323316676046854', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1293819326915473408', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1284389055317377024', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1276487707137622016', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1252106437771362304', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264787678299635714', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1293794178481246208', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256814877168955392', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1241455239020109824', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1245657335185289217', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1271342274673336321', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264456892287516673', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1252530466483326976', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290574228799000576', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1277835807668293634', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1270318341568311297', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1252963239102742528', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1279044260910768128', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1287350883337023488', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1286748819657498624', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257233121868754945', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1258297041324736515', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1269864117298290688', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1281657157524623361', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290601509692903426', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1245354133936357377', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255456506373431297', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251880057079037954', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251756454123646976', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1280518952993476608', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1261932738090807296', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1298193661562204160', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1289844042461847552', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1274067350757801991', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1283079389773783041', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250802045118013440', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1246197620965597186', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1269998140318453761', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1278234789816958981', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1262675074647232512', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1278287445688291328', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1280842086477004801', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1242086762488438784', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264819030252191745', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1235098174139904003', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257035748492140550', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290585232647888898', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1268591580409204740', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1243479129074343937', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1239493592441380865', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264890090477817857', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1254804688513490944', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1267165202497310724', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1280820129090154496', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1296767903522607105', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256917596659736576', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1279414966286770176', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1275314360316039169', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1245262127604142080', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1262113116869009412', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1252527835648049155', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1247804636150423554', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1270377330402344969', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1286035909302013953', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1268778033214894081', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1268052677499346946', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1263413745235214336', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1287643276024123392', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249669004060438528', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1244146493021454337', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1271428293959581698', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255392951011868675', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1259128410313560065', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1274641713643040769', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1269515546220998656', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1297166675578511360', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1256487003258073088', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255110297456607233', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1276510116355981314', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1260104247301021696', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1263913228456931329', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1290162193577603074', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1276149134119051265', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1285938937882710018', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1295328782149128192', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1247386277202272264', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1273259522090565637', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253221646955094021', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1281069201600503808', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1271078116165857284', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1246693443075739648', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1293413699735224321', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1261916412018331653', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1255864577025290245', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1282295492295241729', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1236202092089561088', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1276522251312078851', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1271349759635329025', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1263030657393057792', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253333080443457536', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1230181822123868160', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1259714196134080513', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1270806076871622656', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246003070217203714', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251512123798302720', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1254851851960401920', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255373760636616706', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253928185705758720', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1286633960118849536', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1274989869383680000', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1281130275364311040', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1275324327932674049', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1248109487199666176', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1295323873840250880', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246160979483910148', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1268076054528135168', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1297052270333505536', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1282270808426020864', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264921606398324740', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1260792311602016256', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1244886649248649217', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1236650736571813891', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257329379811700736', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250305606855974913', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1275307374052507648', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253324776212279296', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1271471733602689025', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1265624833095852034', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1299610517154168832', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1244899845162315777', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249777257058652163', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257519513374949376', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249684905249759233', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251196829267615745', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1281828733268242433', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253963605353148417', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1280151787123679233', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1286359115514748929', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1245269092912807936', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1241612203066785792', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1258304288167792640', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1228940442584174592', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1289541290820947969', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1262651491153821698', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1281183663175217152', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256677908397076481', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1240305122690904064', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246333232158777345', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251541566361088002', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257392722161401863', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1260904325301153792', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1264414201893838849', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1244885898644336640', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249012926138273793', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1254793167775453188', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250481641954447360', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1290522239209631744', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1287426714721611776', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1267431306591440896', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1300343823944626177', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1275007090646450177', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251405718416064512', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1251429978794672128', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1270937741908480000', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246754464855478278', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1263379900884451329', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1282923720609345537', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1281121864924921856', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1298177216401027072', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1259391006082031616', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1249953437145616389', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1256509993941114880', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1246459886222946304', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1265240562267041792', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1264434088519233537', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251159592672694274', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1293072674491633665', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1281975571271032834', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1248658138854617088', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1299688020325654529', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1238458492450754560', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253964033650286592', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1288041022694596608', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1273328822071496704', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1245615058354204672', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1251016562477355013', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1286209802172010498', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1260976926795104256', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1267409228790145025', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1244527407471747072', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1272983933215477766', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1258621063208058881', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1279386113526755328', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1269132293274087431', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1281550508566761479', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1246011670742339584', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1238512149900808192', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1275489711050633216', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1293088573181366274', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1248497877770330112', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255423779729297408', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250453766069014528', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1255669656372854789', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1259766094572773377', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1250692537154748419', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1270597167321923585', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1278996633125085184', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1252870268919242752', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1265148163415031808', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1290934870831661058', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250343473804263450', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1253282988755955717', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1295301416886599682', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250031936707280896', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1248543152883011584', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1279457451725766656', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1298636128527032321', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1296520638627057666', 'label': 1},
#  {'topic_id': 'covid-19', 'id_str': '1255132260623249411', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1257942028782120960', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1251421761427603456', 'label': 0},
#  {'topic_id': 'covid-19', 'id_str': '1250353176512872449', 'label': 0}]

# %%
import jsonlines

with jsonlines.open('predictions_ct21-5-epochs.jsonl', 'w') as writer:
    writer.write_all(predictions)
